# %%
from gensim.models.doc2vec import Doc2Vec
from top2vec import Top2Vec

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      1.0.0
# anytree                      2.8.0
# appnope                      0.1.3
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# astunparse                   1.6.3
# attrs                        21.4.0
# backcall                     0.2.0
# beautifulsoup4               4.11.1
# bertopic                     0.10.0
# bhc                          0.0.3+6.gd6659b3
# BHClustering                 0.0.3
# bleach                       5.0.0
# blis                         0.7.7
# cached-property              1.5.2
# cachetools                   5.0.0
# catalogue                    2.0.7
# certifi                      2021.10.8
# cffi                         1.15.0
# charset-normalizer           2.0.12
# click                        8.0.4
# cycler                       0.11.0
# cymem                        2.0.6
# ...

# %%
# !pwd
# Out:
# /Users/taikitanaka/vsc/tdbccr/ipynb/judgit

# %%
dmodel = Doc2Vec.load('../../public/data/visdata_doc2vec.model')
tmodel = Top2Vec.load('../../public/data/visdata_top2vec.model')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/16/qdqq8l5d0kg5tj0qdylzkx7c0000gp/T/ipykernel_22631/720591643.py in <module>
# ----> 1 dmodel = Doc2Vec.load('../../public/data/visdata_doc2vec.model')
#       2 tmodel = Top2Vec.load('../../public/data/visdata_top2vec.model')
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/gensim/models/doc2vec.py in load(cls, *args, **kwargs)
#     811                 "Try loading older model using gensim-3.8.3, then re-saving, to restore "
#     812                 "compatibility with current code.")
# --> 813             raise ae
#     814
#     815     def estimate_memory(self, vocab_size=None, report=None):
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/gensim/models/doc2vec.py in load(cls, *args, **kwargs)
#     805         """
#     806         try:
# ...
